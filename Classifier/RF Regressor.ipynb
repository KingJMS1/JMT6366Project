# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from itertools import product
import json 

import pprint
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.pipeline import Pipeline
from preprocessor import get_train_environment

# %% [markdown]
# # Tuning model

# %%
# Define parameter grid
n_estimators = list(range(100, 1100, 100))
max_depth = list(range(3, 11, 1))
param_grid = [(n, d) for n in n_estimators for d in max_depth]

# Initialize variables to track the best parameters
best_params = None
best_score = float('inf')
model_performance = []

# Iterate over all combinations of parameters
for n, d in param_grid:
    mse_scores = []
    print(n,d)
    
    # Iterate over folds
    envGen = get_train_environment(n_splits=5)
    stats, X, X_holdout, y, y_holdout = next(envGen)
    
    for fold, stats, X_train, X_test, y_train, y_test in envGen:
        if len(X_train) == 0 or len(X_test) == 0:
            print(f"Skipping empty fold: {fold}")
            continue

        # Create and fit the model
        model = RandomForestRegressor(n_estimators=n, max_depth=d)
        model.fit(X_train, y_train)

        # Predict and evaluate
        predictions = model.predict(X_test)

        # Check if predictions are valid
        if not np.any(np.isnan(predictions)):
            mse = mean_squared_error(y_test, predictions)
            # print("Mean Squared Error: ", mse)
            mse_scores.append(mse)
            performance = {
                'n_estimators': n,
                'max_depth': d,
                'Fold':fold,
                'MSE': mse
            }
            model_performance.append(performance)
        else:
            print(f"Invalid predictions in fold: {fold}")       

    # Average MSE across folds for current parameter combination
    avg_mse = np.mean(mse_scores)
    # Update best parameters if current combination is better
    if avg_mse < best_score:
        best_score = avg_mse
        best_params = (n, d)
# Out:
# 100 3
# Found cached folds, using those
# 100 4
# Found cached folds, using those
# 100 5
# Found cached folds, using those
# 100 6
# Found cached folds, using those
# 100 7
# Found cached folds, using those
# 100 8
# Found cached folds, using those
# 100 9
# Found cached folds, using those
# 100 10
# Found cached folds, using those
# 200 3
# Found cached folds, using those
# 200 4
# Found cached folds, using those
# 200 5
# Found cached folds, using those
# 200 6
# Found cached folds, using those
# 200 7
# Found cached folds, using those
# 200 8
# Found cached folds, using those
# 200 9
# Found cached folds, using those
# 200 10
# Found cached folds, using those
# 300 3
# Found cached folds, using those
# 300 4
# Found cached folds, using those
# 300 5
# Found cached folds, using those
# 300 6
# Found cached folds, using those
# 300 7
# Found cached folds, using those
# 300 8
# Found cached folds, using those
# 300 9
# Found cached folds, using those
# 300 10
# Found cached folds, using those
# 400 3
# Found cached folds, using those
# 400 4
# Found cached folds, using those
# 400 5
# Found cached folds, using those
# 400 6
# Found cached folds, using those
# 400 7
# Found cached folds, using those
# 400 8
# Found cached folds, using those
# 400 9
# Found cached folds, using those
# 400 10
# Found cached folds, using those
# 500 3
# Found cached folds, using those
# 500 4
# Found cached folds, using those
# 500 5
# Found cached folds, using those
# 500 6
# Found cached folds, using those
# 500 7
# Found cached folds, using those
# 500 8
# Found cached folds, using those
# 500 9
# Found cached folds, using those
# 500 10
# Found cached folds, using those
# 600 3
# Found cached folds, using those
# 600 4
# Found cached folds, using those
# 600 5
# Found cached folds, using those
# 600 6
# Found cached folds, using those
# 600 7
# Found cached folds, using those
# 600 8
# Found cached folds, using those
# 600 9
# Found cached folds, using those
# 600 10
# Found cached folds, using those
# 700 3
# Found cached folds, using those
# 700 4
# Found cached folds, using those
# 700 5
# Found cached folds, using those
# 700 6
# Found cached folds, using those
# 700 7
# Found cached folds, using those
# 700 8
# Found cached folds, using those
# 700 9
# Found cached folds, using those
# 700 10
# Found cached folds, using those
# 800 3
# Found cached folds, using those
# 800 4
# Found cached folds, using those
# 800 5
# Found cached folds, using those
# 800 6
# Found cached folds, using those
# 800 7
# Found cached folds, using those
# 800 8
# Found cached folds, using those
# 800 9
# Found cached folds, using those
# 800 10
# Found cached folds, using those
# 900 3
# Found cached folds, using those
# 900 4
# Found cached folds, using those
# 900 5
# Found cached folds, using those
# 900 6
# Found cached folds, using those
# 900 7
# Found cached folds, using those
# 900 8
# Found cached folds, using those
# 900 9
# Found cached folds, using those
# 900 10
# Found cached folds, using those
# 1000 3
# Found cached folds, using those
# 1000 4
# Found cached folds, using those
# 1000 5
# Found cached folds, using those
# 1000 6
# Found cached folds, using those
# 1000 7
# Found cached folds, using those
# 1000 8
# Found cached folds, using those
# 1000 9
# Found cached folds, using those
# 1000 10
# Found cached folds, using those

# %%
# Aggregate MSE values for each (n_estimators, max_depth) pair
mse_aggregate = {}

for entry in model_performance:
    key = (entry['n_estimators'], entry['max_depth'])
    if key not in mse_aggregate:
        mse_aggregate[key] = []
    mse_aggregate[key].append(entry['MSE'])

# Calculate average MSE for each pair
average_mse = {k: sum(v)/len(v) for k, v in mse_aggregate.items()}

# Prepare data for plotting
n_estimators = [k[0] for k in average_mse.keys()]
max_depth = [k[1] for k in average_mse.keys()]
avg_mse = list(average_mse.values())

plt.figure(figsize=(28,9))
plt.bar(range(len(avg_mse)), avg_mse, tick_label=[f"{n} / {d}" for n, d in zip(n_estimators, max_depth)])
plt.xlabel('Parameter Pair (n_estimators / max_depth)')
plt.ylabel('Average MSE')
plt.title('(RandomForestRegressor)Average MSE for Each Parameter Pair')
plt.show()

# %%
print(f"Best parameters: n_estimators={best_params[0]}, max_depth={best_params[1]} with MSE: {best_score}")
# Out:
# Best parameters: n_estimators=500, max_depth=10 with MSE: 0.4084262590344349

# %% [markdown]
# # Find important feature

# %%
envGen = get_train_environment(n_splits=5)
# The holdout set is not included in the cross validation folds, use it at the very end to evaluate overall performance
stats, X, X_holdout, y, y_holdout = next(envGen)

# Initialize variables to track important features num
print(len(X[0]))
featureNums = range(1, len(X[0]), 10)
featureNumMSEs = {}

# Cross validation folds
for fold, stats, X_train, X_test, y_train, y_test in envGen:
    print(f"Fold: {fold}")
    
    model = RandomForestRegressor(n_estimators=best_params[0], max_depth=best_params[1])
    model.fit(X_train, y_train)

    # print(model.feature_importances_)
    # make predictions for test data and evaluate
    predictions = model.predict(X_test)
    mse = mean_squared_error(y_test, predictions)
    print("Overall Fold Mean Squared Error: ", mse)
    
    thresholds = enumerate(model.feature_importances_)
    thresholds = [x for x in thresholds]
    thresholds.sort(key=lambda x: x[1], reverse=True)
    
    eps = 0.000001
    lastMSE = None
    for featureNum in featureNums:
        selectedFeatures = [i for i, x in thresholds[:featureNum]]
        
        model = RandomForestRegressor(n_estimators=best_params[0], max_depth=best_params[1])
        XT = X_train[:, selectedFeatures]
        model.fit(XT, y_train)
        
        predictions = model.predict(X_test[:, selectedFeatures])
        mse = mean_squared_error(y_test, predictions)
        
        if lastMSE is not None:
            if np.abs(mse - lastMSE) < eps:
                print(np.abs(mse - lastMSE))
                print(mse)
                break
            else:
                lastMSE = mse
        else:
            lastMSE = mse
        
        if featureNum in featureNumMSEs:
            featureNumMSEs[featureNum].append(mse)
        else:
            featureNumMSEs[featureNum] = [mse]
        
        print(f"FeatureNum: {featureNum}")
        print("FeatureNum Mean Squared Error: ", mse)

avgFeatureNumMSEs = {x: np.mean(featureNumMSEs[x]) for x in featureNumMSEs}
optimal_FeatureNum = [min(avgFeatureNumMSEs, key=avgFeatureNumMSEs.get),avgFeatureNumMSEs[min(avgFeatureNumMSEs, key=avgFeatureNumMSEs.get)]]
print("Optimal # of features: ",optimal_FeatureNum[0],", MSE: ",optimal_FeatureNum[1])
# Out:
# Found cached folds, using those
# 1574
# Fold: 0
# Overall Fold Mean Squared Error:  0.4240386247706916
# FeatureNum: 1
# FeatureNum Mean Squared Error:  0.9692687186140988
# FeatureNum: 11
# FeatureNum Mean Squared Error:  0.4526958680241367
# FeatureNum: 21
# FeatureNum Mean Squared Error:  0.42656789495355474
# FeatureNum: 31
# FeatureNum Mean Squared Error:  0.4216410777893457
# FeatureNum: 41
# FeatureNum Mean Squared Error:  0.41755220097980034
# FeatureNum: 51
# FeatureNum Mean Squared Error:  0.41967710008841297
# FeatureNum: 61
# FeatureNum Mean Squared Error:  0.42024727370885345
# FeatureNum: 71
# FeatureNum Mean Squared Error:  0.4203658506869255
# FeatureNum: 81
# FeatureNum Mean Squared Error:  0.4189457482885198
# FeatureNum: 91
# FeatureNum Mean Squared Error:  0.41913916068607276
# FeatureNum: 101
# FeatureNum Mean Squared Error:  0.42236000868467916
# FeatureNum: 111
# FeatureNum Mean Squared Error:  0.42204302256776405
# FeatureNum: 121
# FeatureNum Mean Squared Error:  0.4226269356386399
# FeatureNum: 131
# FeatureNum Mean Squared Error:  0.4226496699248632
# FeatureNum: 141
# FeatureNum Mean Squared Error:  0.4239148500561606
# FeatureNum: 151
# FeatureNum Mean Squared Error:  0.42260071604049565
# FeatureNum: 161
# FeatureNum Mean Squared Error:  0.422750216177275
# FeatureNum: 171
# FeatureNum Mean Squared Error:  0.42380851775246475
# FeatureNum: 181
# FeatureNum Mean Squared Error:  0.422705762920878
# FeatureNum: 191
# FeatureNum Mean Squared Error:  0.42330061898850546
# FeatureNum: 201
# FeatureNum Mean Squared Error:  0.42391273440321947
# FeatureNum: 211
# FeatureNum Mean Squared Error:  0.4225446291502209
# FeatureNum: 221
# FeatureNum Mean Squared Error:  0.42162552504078954
# FeatureNum: 231
# FeatureNum Mean Squared Error:  0.4229289743786834
# FeatureNum: 241
# FeatureNum Mean Squared Error:  0.4232895468302749
# FeatureNum: 251
# FeatureNum Mean Squared Error:  0.42295576156280634
# FeatureNum: 261
# FeatureNum: 1251
# FeatureNum Mean Squared Error:  0.4173551679362618
# FeatureNum: 1261
# FeatureNum Mean Squared Error:  0.41716573204851604
# FeatureNum: 1271
# FeatureNum Mean Squared Error:  0.41626826234580483
# FeatureNum: 1281
# FeatureNum Mean Squared Error:  0.4175274244909046
# FeatureNum: 1291
# FeatureNum Mean Squared Error:  0.4167905270055696
# FeatureNum: 1301
# FeatureNum Mean Squared Error:  0.4181890349199204
# FeatureNum: 1311
# FeatureNum Mean Squared Error:  0.416594919439625
# FeatureNum: 1321
# FeatureNum Mean Squared Error:  0.4162144560296343
# FeatureNum: 1331
# FeatureNum Mean Squared Error:  0.4158254444824632
# FeatureNum: 1341
# FeatureNum Mean Squared Error:  0.4156788061917284
# FeatureNum: 1351
# FeatureNum Mean Squared Error:  0.4175603402283586
# FeatureNum: 1361
# FeatureNum Mean Squared Error:  0.416494211344958
# FeatureNum: 1371
# FeatureNum Mean Squared Error:  0.4153397148907569
# FeatureNum: 1381
# FeatureNum Mean Squared Error:  0.4171954543945546
# FeatureNum: 1391
# FeatureNum Mean Squared Error:  0.417584954902231
# FeatureNum: 1401
# FeatureNum Mean Squared Error:  0.4164443669157867
# FeatureNum: 1411
# FeatureNum Mean Squared Error:  0.4157924961827167
# FeatureNum: 1421
# FeatureNum Mean Squared Error:  0.41705254373287354
# FeatureNum: 1431
# FeatureNum Mean Squared Error:  0.41736854422467623
# FeatureNum: 1441
# FeatureNum Mean Squared Error:  0.4174696475705237
# FeatureNum: 1451
# FeatureNum Mean Squared Error:  0.4163144492618517
# FeatureNum: 1461
# FeatureNum Mean Squared Error:  0.4166279863118026
# FeatureNum: 1471
# FeatureNum Mean Squared Error:  0.4180969250143448
# FeatureNum: 1481
# FeatureNum Mean Squared Error:  0.4152420627539776
# FeatureNum: 1491
# FeatureNum Mean Squared Error:  0.4167644966847863
# FeatureNum: 1501
# FeatureNum Mean Squared Error:  0.41660071506210583
# FeatureNum: 1511
# FeatureNum Mean Squared Error:  0.41783375300386444
# FeatureNum: 1521
# FeatureNum Mean Squared Error:  0.4159767433262285
# FeatureNum: 1531
# FeatureNum Mean Squared Error:  0.4160905728309346
# FeatureNum: 1541
# FeatureNum Mean Squared Error:  0.41684209918932774
# FeatureNum: 1551
# FeatureNum Mean Squared Error:  0.4189419805429188
# FeatureNum: 1561
# FeatureNum Mean Squared Error:  0.4180073483098928
# FeatureNum: 1571
# FeatureNum Mean Squared Error:  0.41599367534224096
# Optimal # of features:  81 , MSE:  0.4056624083200048

# %%
ax = sns.lineplot(pd.Series(avgFeatureNumMSEs))
ax.set_xlabel("Num of Features")
ax.set_ylabel("Test MSE")
ax.set_title("RandomForestRegressor feature number vs MSE")
# Out:
# Text(0.5, 1.0, 'RandomForestRegressor feature number vs MSE')

# %%
ax = sns.lineplot(pd.Series(avgFeatureNumMSEs)[1:])
ax.set_xlabel("Num of Features")
ax.set_ylabel("Test MSE")
ax.set_title("RandomForestRegressor feature number vs MSE (without only 1 feature model)")
# Out:
# Text(0.5, 1.0, 'RandomForestRegressor feature number vs MSE (without only 1 feature model)')

# %% [markdown]
# # Create final RandomForestRegressor model after tuning & select important features

# %%
envGen = get_train_environment(n_splits=50)
# The holdout set is not included in the cross validation folds, use it at the very end to evaluate overall performance
stats, X, X_holdout, y, y_holdout = next(envGen)

final_mses = []
final_selection_intersection = set()
allSelecteds = []

# Cross validation folds
for fold, stats, X_train_fold, X_test_fold, y_train_fold, y_test_fold in envGen:
    print(f"Fold: {fold}")
    
    model = RandomForestRegressor(n_estimators=best_params[0], max_depth=best_params[1])
    model.fit(X_train_fold, y_train_fold)

    print(model.feature_importances_)
    # make predictions for test data and evaluate
    pre_predictions = model.predict(X_test_fold)

    pre_mse = mean_squared_error(y_test_fold, pre_predictions)
    print("Pre Selection MSE: ", pre_mse)
    
    thresholds = enumerate(model.feature_importances_)
    thresholds = [x for x in thresholds]
    thresholds.sort(key=lambda x: x[1], reverse=True)
    
    selectedFeatures = [i for i, x in thresholds[:optimal_FeatureNum[0]]]
    allSelecteds.append(selectedFeatures)
    
    if len(final_selection_intersection) == 0:
        final_selection_intersection = final_selection_intersection.union(selectedFeatures)
    else:
        final_selection_intersection = final_selection_intersection.intersection(selectedFeatures)
    
    model = RandomForestRegressor(n_estimators=best_params[0], max_depth=best_params[1])
    
    XT = X_train_fold[:, selectedFeatures]
    model.fit(XT, y_train_fold)

    post_predictions = model.predict(X_test_fold[:, selectedFeatures])
    post_mse = mean_squared_error(y_test_fold, post_predictions)
    print("Post Selection MSE: ", post_mse)
    final_mses.append(post_mse)
# Out:
# Found cached folds, using those
# Fold: 0
# [0.02996174 0.00137679 0.00026427 ... 0.00708767 0.00634547 0.02461687]
# Pre Selection MSE:  0.4094846357024055
# Post Selection MSE:  0.4239036992809178
# Fold: 1
# [0.02962077 0.00132615 0.00025002 ... 0.0075978  0.00626893 0.02795335]
# Pre Selection MSE:  0.5625431737166039
# Post Selection MSE:  0.5568185173122658
# Fold: 2
# [0.02873562 0.00130238 0.0002326  ... 0.00804764 0.00608524 0.02586309]
# Pre Selection MSE:  0.5021381294709908
# Post Selection MSE:  0.5017849045435101
# Fold: 3
# [0.02897357 0.00123537 0.00028382 ... 0.00715356 0.00641965 0.0263018 ]
# Pre Selection MSE:  0.39410110406540455
# Post Selection MSE:  0.3878081584618073
# Fold: 4
# [0.0284269  0.00125334 0.00027947 ... 0.00781317 0.00598761 0.02665709]
# Pre Selection MSE:  0.337902834632517
# Post Selection MSE:  0.34326922169899926
# Fold: 5
# [0.02944205 0.0010453  0.00024106 ... 0.00689562 0.00580869 0.02663991]
# Pre Selection MSE:  0.5256108513376677
# Post Selection MSE:  0.5254619450683675
# Fold: 6
# [0.0283205  0.00134172 0.00031185 ... 0.00788146 0.00618009 0.0268128 ]
# Pre Selection MSE:  0.3713938323492166
# Post Selection MSE:  0.36534311234256395
# Fold: 7
# [0.0287503  0.00107758 0.00030368 ... 0.0075855  0.00606879 0.02609534]
# Pre Selection MSE:  0.4074546690857431
# Post Selection MSE:  0.4082726678474303
# Fold: 8
# [0.02893798 0.00118577 0.00035929 ... 0.00737338 0.00571312 0.02614058]
# Pre Selection MSE:  0.4812222971945742
# Post Selection MSE:  0.47781932646280384
# Fold: 9
# [0.02936184 0.00144459 0.0002751  ... 0.00754577 0.00641294 0.0267041 ]
# Pre Selection MSE:  0.3118245840758613
# Post Selection MSE:  0.3104108385082139
# Fold: 10
# [0.02833742 0.0011111  0.00023101 ... 0.00824874 0.0059101  0.02698294]
# Pre Selection MSE:  0.44285129702034687
# Post Selection MSE:  0.43718051243324196
# Fold: 11
# [0.02952512 0.00112099 0.00028158 ... 0.00815444 0.006095   0.028614  ]
# Pre Selection MSE:  0.4661732004714459
# Post Selection MSE:  0.46479185369239906
# Fold: 12
# [0.02903148 0.00128092 0.0002765  ... 0.00668796 0.00605699 0.02749272]
# Pre Selection MSE:  0.46386822392847316
# Post Selection MSE:  0.45790598376648783
# Fold: 13
# [0.02967292 0.00110798 0.00032048 ... 0.0064873  0.00634284 0.02601254]
# Pre Selection MSE:  0.3553537561794637
# Post Selection MSE:  0.35634197690636377
# Fold: 14
# [0.0294055  0.0010763  0.00028505 ... 0.00763779 0.00666345 0.02508392]
# Pre Selection MSE:  0.4328734479988755
# Post Selection MSE:  0.4257732505601359
# Fold: 15
# [0.0287444  0.00106693 0.00028566 ... 0.00760761 0.00598592 0.02557892]
# Pre Selection MSE:  0.3717712859798746
# Post Selection MSE:  0.37078203655081066
# Fold: 16
# [0.02885949 0.00100278 0.00025609 ... 0.00778892 0.00628136 0.02773222]
# Pre Selection MSE:  0.591725641031379
# Post Selection MSE:  0.5849324556211393
# Fold: 17
# [0.02878347 0.00124943 0.00026976 ... 0.00746221 0.00617945 0.02704666]
# Pre Selection MSE:  0.28045126466158943
# Post Selection MSE:  0.2704337335001013
# Fold: 18
# [0.02881212 0.00108801 0.00030657 ... 0.00948323 0.00590576 0.02777769]
# Pre Selection MSE:  0.4303824280512409
# Post Selection MSE:  0.4249975755435753
# Fold: 19
# [0.0284773  0.00110797 0.00027661 ... 0.00741599 0.00653967 0.02646174]
# Pre Selection MSE:  0.31251058024380857
# Post Selection MSE:  0.31138964768430827
# Fold: 20
# [0.02897891 0.00110059 0.00032241 ... 0.00733577 0.00608952 0.02717955]
# Pre Selection MSE:  0.39125323648880134
# Post Selection MSE:  0.39976666691154655
# Fold: 21
# [0.02873599 0.00133396 0.00036919 ... 0.00756421 0.00644813 0.0254263 ]
# Pre Selection MSE:  0.40006854351433924
# Post Selection MSE:  0.3978945711537686
# Fold: 22
# [0.0300487  0.00146987 0.00029466 ... 0.00741316 0.00615559 0.02671167]
# Pre Selection MSE:  0.39251574114336
# Post Selection MSE:  0.39860422808307816
# Fold: 23
# [0.02818769 0.00102224 0.00022487 ... 0.00833899 0.0063889  0.02783598]
# Pre Selection MSE:  0.4162336093048056
# Post Selection MSE:  0.4255273952046791
# Fold: 24
# [0.02885703 0.00128828 0.00026955 ... 0.00766111 0.00606629 0.02692688]
# Pre Selection MSE:  0.35847882104488304
# Post Selection MSE:  0.35767136381967773
# Fold: 25
# [0.0286492  0.00126234 0.00025902 ... 0.00670321 0.00593954 0.02589227]
# Pre Selection MSE:  0.3900905468359813
# Post Selection MSE:  0.37921139618823757
# Fold: 26
# [0.02953552 0.00112866 0.00029963 ... 0.00710797 0.00613376 0.025655  ]
# Pre Selection MSE:  0.3764835695974793
# Post Selection MSE:  0.37612842290368453
# Fold: 27
# [0.02910308 0.00139248 0.00028309 ... 0.00678664 0.00613826 0.02468237]
# Pre Selection MSE:  0.43198635165196686
# Post Selection MSE:  0.43171171022337057
# Fold: 28
# [0.02919316 0.00102939 0.00033403 ... 0.0078439  0.00623405 0.02788232]
# Pre Selection MSE:  0.3424955385324916
# Post Selection MSE:  0.3361346379457632
# Fold: 29
# [0.02940928 0.00130309 0.00027681 ... 0.00692079 0.00626839 0.02867809]
# Pre Selection MSE:  0.4455352255567457
# Post Selection MSE:  0.4437401512600511
# Fold: 30
# [0.02890329 0.00124966 0.00030787 ... 0.00758823 0.00628573 0.02707662]
# Pre Selection MSE:  0.3980576865412446
# Post Selection MSE:  0.40019709556356414
# Fold: 31
# [0.0290938  0.00135226 0.00031124 ... 0.00763914 0.00612492 0.02789144]
# Pre Selection MSE:  0.3446215805820396
# Post Selection MSE:  0.34670656979120623
# Fold: 32
# [0.0292756  0.00118346 0.00032492 ... 0.00730096 0.00565863 0.02624284]
# Pre Selection MSE:  0.4450051208038735
# Post Selection MSE:  0.435942979837887
# Fold: 33
# [0.02914309 0.00123191 0.00029098 ... 0.00760433 0.0056576  0.02783061]
# Pre Selection MSE:  0.43950643141555845
# Post Selection MSE:  0.4321636875623166
# Fold: 34
# [0.02856046 0.00119407 0.00033648 ... 0.00813073 0.00614364 0.02692428]
# Pre Selection MSE:  0.35304403330627265
# Post Selection MSE:  0.36028322615429753
# Fold: 35
# [0.02911893 0.00113392 0.0002081  ... 0.00824423 0.00626107 0.02623279]
# Pre Selection MSE:  0.43054908629162814
# Post Selection MSE:  0.4194755908664716
# Fold: 36
# [0.02979207 0.00121207 0.00027786 ... 0.00727427 0.00660412 0.02647019]
# Pre Selection MSE:  0.4329849678130793
# Post Selection MSE:  0.42605834285394295
# Fold: 37
# [0.02881864 0.00130375 0.00030017 ... 0.00768657 0.00642444 0.02616527]
# Pre Selection MSE:  0.384753701762421
# Post Selection MSE:  0.3788041598010884
# Fold: 38
# [0.02842142 0.00113323 0.00025802 ... 0.00748443 0.00624322 0.02713833]
# Pre Selection MSE:  0.28831900763423873
# Post Selection MSE:  0.2860757801225345
# Fold: 39
# [0.02925497 0.00120302 0.00028111 ... 0.00811974 0.00578075 0.02537829]
# Pre Selection MSE:  0.440657710584383
# Post Selection MSE:  0.4537440619317615
# Fold: 40
# [0.02938467 0.00150403 0.00025663 ... 0.00690413 0.00620814 0.02542587]
# Pre Selection MSE:  0.49735980937827484
# Post Selection MSE:  0.5109455637217636
# Fold: 41
# [0.02804763 0.00135867 0.0002709  ... 0.00744148 0.00630561 0.02640874]
# Pre Selection MSE:  0.37457086149078817
# Post Selection MSE:  0.38349617095851285
# Fold: 42
# [0.02901412 0.00127645 0.00032595 ... 0.00753396 0.00589181 0.02674796]
# Pre Selection MSE:  0.4989788286867479
# Post Selection MSE:  0.5002417995053496
# Fold: 43
# [0.02939381 0.00135439 0.00029694 ... 0.00755734 0.0066702  0.02532801]
# Pre Selection MSE:  0.4426554734791231
# Post Selection MSE:  0.45068333211775846
# Fold: 44
# [0.02872275 0.00145349 0.00032193 ... 0.00812092 0.00629245 0.02649834]
# Pre Selection MSE:  0.36642057921487337
# Post Selection MSE:  0.36392839001391664
# Fold: 45
# [0.02879058 0.00114602 0.00030639 ... 0.00771461 0.00667576 0.02749104]
# Pre Selection MSE:  0.4946082453505884
# Post Selection MSE:  0.4912576996024471
# Fold: 46
# [0.0284272  0.00112639 0.00032866 ... 0.00745861 0.00638709 0.02718207]
# Pre Selection MSE:  0.42988892489889846
# Post Selection MSE:  0.4222671318273411
# Fold: 47
# [0.02818759 0.00130773 0.00028471 ... 0.00778218 0.00596553 0.02743569]
# Pre Selection MSE:  0.36102178281853364
# Post Selection MSE:  0.35855754350899643
# Fold: 48
# [0.02986367 0.00120897 0.00027954 ... 0.00701655 0.00598975 0.02665416]
# Pre Selection MSE:  0.4706584630265524
# Post Selection MSE:  0.47710404838990783
# Fold: 49
# [0.02831201 0.00122634 0.00030155 ... 0.00695103 0.00606203 0.02612562]
# Pre Selection MSE:  0.39413082344509726
# Post Selection MSE:  0.3921588953405952

# %%
print("Final RandomForestRegressor model's avg. MSE:",np.mean(final_mses))
# Out:
# Final RandomForestRegressor model's avg. MSE: 0.4128380806190192

# %%
def feature_labels(features):
    data = pd.read_csv("FinalData.csv")
    data = data.drop(["Name", "appid", 'ln.pricep1', "Unnamed: 0"], axis=1)
    data_columns = data.columns.tolist()
    return [x for i, x in enumerate(data_columns) if i in features]

# %%
rf_reg_final_features = feature_labels(final_selection_intersection)
print(rf_reg_final_features)
# Out:
# ['release_date', 'Single-player', 'Full controller support', 'Steam Trading Cards', 'Steam Cloud', 'genre_Adventure', 'genre_Casual', 'genre_Indie', 'genre_Simulation', 'tag_Indie', 'Tracked Controller Support', 'Profile Features Limited', 'tag_Simulation', 'genre_Early Access', 'pub_HIKARI FIELD', 'tag_Casual', 'tag_Free to Play', 'In-App Purchases', 'tag_Third-Person Shooter', 'tag_Clicker', 'tag_Idler', 'tag_Sexual Content', 'tag_Hentai', 'genre_Massively Multiplayer', 'tag_PvP', 'tag_Wargame', 'tag_Battle Royale', 'tag_Social Deduction', 'pub_Slitherine Ltd.', 'tag_MMORPG', 'dev_FC Maker', 'naccus', 'ln.Pos_Reviews', 'ln.dlcp1', 'ln.curatorsp1', 'ln.steam_achievementsp1', 'ln.PaidDLCsp1', 'ln.totDLCPricep1', 'ln.numUpdatesp1', 'ln.fullAudiop1', 'ln.interfacep1', 'ln.subtitlesp1', 'ln.all-time_peak_ccu', 'ln.last_30_days_avg_ccu']
